# %%
import multion
import json

# %%
multion.login()
# Out:
# Already logged in

# %%
user_details = {
    'fullName':"Shirley Xu",
    'gender': "Female",
    'email': "laixu@gmail.com",
    'phoneNumber': "4159168995",
    'address': "1 Shield Ave",
    'Date of Birth':'01/01/2020',
    'city': "Davis",
    'state': "CA",
    'country': "United States",
    'zipCode': "95616",
    'passportNumber': "E003567",
    'password': "78IKtyJK"}

# %%
prompt = f"Create an account for this user: {json.dumps(user_details)}"

# %%
response = multion.new_session({"input": prompt, "url": "https://www.united.com/en/US/account/enroll/profile"})
# Out:
#   Cell In[45], line 1
#     prompt = f"Can you create the log in and return the account number for Shirley Xu. Details: {json.dumps(user_details)}", "url": "https://www.united.com/en/US/account/enroll/profile"
#                                                                                                                                   ^
# SyntaxError: invalid syntax

# %%
prompt
# Out:
# 'Can you create the log in and return the account number for Shirley Xu. Details: {"fullName": "Shirley Xu", "gender": "Female", "email": "laixu@gmail.com", "phoneNumber": "4159168995", "address": "1 Shield Ave", "Date of Birth": "01/01/2020", "city": "Davis", "state": "CA", "country": "United States", "zipCode": "95616", "passportNumber": "E003567", "password": "78IKtyJK"}'

# %%
print(response)
# Out:
# {'url': 'https://www.united.com/en/US/account/enroll/profile', 'screenshot': 'data:image/png;base64,...', 'tabId': '647147453', 'message': 'I am filling in the required fields for creating an account for Shirley Xu and then clicking on the "Continue" button to proceed with the account creation process.\n\n', 'status': 'CONTINUE'}

# %%
multion.new_session
# Out:
# <function multion.multion.new_session(data)>

# %%
tabId = response['tabId']

# %%
response = multion.update_session(tabId, {"input": f"Weather Today","url": "https://www.google.com"})
response
# Out:
# session updated
# {'url': 'https://www.google.com',
#  'screenshot': 'data:image/png;base64,...',
#  'tabId': '647147450',
#  'message': 'The weather today in Hillsborough, CA is partly cloudy with a temperature of 79°F. The precipitation is 10%, humidity is 59%, and the wind speed is 14 mph.\n',
#  'status': 'DONE'}

# %%
response['message']
# Out:
# 'The weather today in Hillsborough, CA is partly cloudy with a temperature of 79°F. The precipitation is 10%, humidity is 59%, and the wind speed is 14 mph.\n'

# %%
multion.get_screenshot(response)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2000x1686>
